# %%
# Dependencies
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt

# %%
names_dict={}
names=['Homer', 'Marge', 'Bart', 'Lisa', 'Maggie', 'Abraham', 'Barney', 'Moe', 'Ned', 'Ralph', 'Nelson']

for name in names:
    #Set name
    entry_name=name
    
    #Get html for name
    url = f'https://www.behindthename.com/name/{entry_name}/top/united-states'

    #Get results
    results=pd.read_html(url)

    #Write name to df:o
    entry_name=results[1]

    #Names with male & female rankings have 7 columns
    if len(list(entry_name.columns))==7:
        #Drop extra columns
        entry_name=entry_name.drop(columns=[2, 3,4,5,6])
    
    #Names with only male or only female rankings have 4 columns    
    elif len(list(entry_name.columns))==4:
        #Drop extra columns
        entry_name=entry_name.drop(columns=[2, 3])

    #Drop first 2 rows
    entry_name=entry_name.drop([0,1])

    #Rename columns
    entry_name=entry_name.rename(columns = {0:'Year', 1: f'{name}'})

    #Replace empty string and - with nan
    entry_name[f'{name}'].replace('', np.nan, inplace=True)
    entry_name[f'{name}'].replace('-', np.nan, inplace=True)

    #Drop nan
    entry_name=entry_name.dropna()

    #Remove hash from rank
    entry_name[name]=entry_name[f'{name}'].str[1:]

    #Write year and rank to integer
    entry_name['Year'] = entry_name['Year'].astype(int)
    entry_name[f'{name}'] = entry_name[f'{name}'].astype(int)

    #Filter for years greater than 1990
    entry_name=entry_name[entry_name['Year']>=1990]
    
    #Reset index to year
    entry_name=entry_name.set_index('Year')
    
    #Write dataframe to dictionary
    names_dict[name]=entry_name

# %%
#Write data frames to list
data_frames=[]

for name in names:
    data_frames.append(names_dict[name])

#Merge dataframes
names_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Year'], how='outer'), data_frames)

#Drop empty columns
names_merged=names_merged.dropna(how='all', axis=1)

# %%
names_merged.plot.line().invert_yaxis()
plt.ylabel('Rank out of 1000 Most Popular Names')
# Out:
# Text(0, 0.5, 'Rank out of 1000 Most Popular Names')

# %%
#Add column for seasons
# Create list with integers within given range   
def createList(r1, r2): 
    return np.arange(r1, r2+1, 1)

# Driver Code 
r1, r2 = 1, 30
seasons=(createList(r1, r2))

#turn array to list
seasons=list(seasons)

#Reverse List Order
seasons.reverse()

#Add seasons list to dataframe
names_merged['Season']=seasons

#Reset index to year
names_merged=names_merged.set_index('Season')

# %%
names_merged
# Out:
#         Lisa  Maggie  Abraham  Ralph  Nelson
# Season
# 30       955     295      191    NaN     655
# 29       877     293      163  950.0     671
# 28       885     248      169    NaN     631
# 27       834     242      157  991.0     620
# 26       754     241      169    NaN     626
# 25       739     238      180    NaN     645
# 24       768     232      182    NaN     581
# 23       708     247      190    NaN     558
# 22       702     229      192  953.0     556
# 21       712     225      194  966.0     572
# 20       693     233      180  953.0     524
# 19       603     214      186  860.0     497
# 18       570     181      188  868.0     467
# 17       500     189      182  759.0     448
# 16       493     211      192  768.0     441
# 15       427     205      193  710.0     452
# 14       372     188      195  658.0     420
# 13       359     190      204  630.0     408
# 12       336     181      200  610.0     407
# 11       295     198      213  583.0     414
# 10       282     224      214  570.0     402
# 9        230     248      208  582.0     397
# 8        194     277      216  544.0     387
# 7        168     256      227  503.0     377
# 6        144     250      232  502.0     356
# 5        123     232      241  490.0     342
# 4        100     281      244  428.0     332
# 3         88     271      254  441.0     319
# 2         83     296      243  405.0     318
# 1         64     288      244  385.0     279

# %%
#Write data frame to csv
names_merged.to_csv("./simpsons_names.csv", sep=',',index=True)
